# %%
import pandas as pd

# %%
#Load the dataset
data = pd.read_csv('/content/drive/MyDrive/5DATA002W.2 Coursework Dataset(25012025v6.0).csv')

# %%
#Display first few rows
data.head()
# Out:
#   Patient_ID  Month_of_Birth   Age     Sex   Occupation T_Stage N_Stage  \
# 0      A0012              12  68.0  Female     Teaching      T1      N1
# 1      A0013              12  50.0  Female      Medical      T2      N2
# 2      A0014              11  58.0  Female  Engineering      T3      N3
# 3      A0015               3  58.0  Female   Technology      T1      N1
# 4      A0016               1  47.0  Female   Multimedia      T2      N1
#
#   6th_Stage             Differentiated  Grade   A_Stage  Tumor_Size  \
# 0       IIA      Poorly differentiated      3  Regional         4.0
# 1      IIIA  Moderately differentiated      2  Regional        35.0
# 2      IIIC  Moderately differentiated      2  Regional        63.0
# 3       IIA      Poorly differentiated      3  Regional        18.0
# 4       IIB      Poorly differentiated      3  Regional        41.0
#
#   Estrogen_Status Progesterone_Status  Regional_Node_Examined  \
# ...

# %%
#Display column names
list(data.columns)
# Out:
# ['Patient_ID',
#  'Month_of_Birth',
#  'Age',
#  'Sex',
#  'Occupation',
#  'T_Stage',
#  'N_Stage',
#  '6th_Stage',
#  'Differentiated',
#  'Grade',
#  'A_Stage',
#  'Tumor_Size',
#  'Estrogen_Status',
#  'Progesterone_Status',
#  'Regional_Node_Examined',
#  'Reginol_Node_Positive',
#  'Survival_Months',
#  'Mortality_Status']

# %%
#Check data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Patient_ID              4024 non-null   object
#  1   Month_of_Birth          4024 non-null   int64
#  2   Age                     4015 non-null   float64
#  3   Sex                     4020 non-null   object
#  4   Occupation              43 non-null     object
#  5   T_Stage                 4024 non-null   object
#  6   N_Stage                 4024 non-null   object
#  7   6th_Stage               4024 non-null   object
#  8   Differentiated          4024 non-null   object
#  9   Grade                   4024 non-null   int64
#  10  A_Stage                 4024 non-null   object
#  11  Tumor_Size              4021 non-null   float64
#  12  Estrogen_Status         4024 non-null   object
#  13  Progesterone_Status     4024 non-null   object
# ...

# %%
#Get dataset dimensions
data.shape
# Out:
# (4024, 18)

# %%
#Count missing values
data.isnull().sum()
# Out:
# Patient_ID                   0
# Month_of_Birth               0
# Age                          9
# Sex                          4
# Occupation                3981
# T_Stage                      0
# N_Stage                      0
# 6th_Stage                    0
# Differentiated               0
# Grade                        0
# A_Stage                      0
# Tumor_Size                   3
# Estrogen_Status              0
# Progesterone_Status          0
# Regional_Node_Examined       1
# Reginol_Node_Positive        0
# Survival_Months              0
# Mortality_Status             0
# dtype: int64

# %%
#Display the percentage of missing values
data.isna().sum()/len(data)*100
# Out:
# Patient_ID                 0.000000
# Month_of_Birth             0.000000
# Age                        0.223658
# Sex                        0.099404
# Occupation                98.931412
# T_Stage                    0.000000
# N_Stage                    0.000000
# 6th_Stage                  0.000000
# Differentiated             0.000000
# Grade                      0.000000
# A_Stage                    0.000000
# Tumor_Size                 0.074553
# Estrogen_Status            0.000000
# Progesterone_Status        0.000000
# Regional_Node_Examined     0.024851
# Reginol_Node_Positive      0.000000
# Survival_Months            0.000000
# Mortality_Status           0.000000
# dtype: float64

# %%
#Numeric variables statistics
data.describe()
# Out:
#        Month_of_Birth          Age        Grade   Tumor_Size  \
# count     4024.000000  4015.000000  4024.000000  4021.000000
# mean         6.481362    54.107098     2.150596    30.419299
# std          3.475442    11.715528     0.638234    21.161080
# min          1.000000   -50.000000     1.000000   -75.000000
# 25%          3.000000    47.000000     2.000000    16.000000
# 50%          6.000000    54.000000     2.000000    25.000000
# 75%         10.000000    61.000000     3.000000    38.000000
# max         12.000000   502.000000     4.000000   140.000000
#
#        Regional_Node_Examined  Reginol_Node_Positive  Survival_Months
# count             4023.000000            4024.000000      4024.000000
# mean                14.373602               4.158052        71.472167
# std                  8.129293               5.109331        25.361855
# min                  1.000000               1.000000         1.000000
# ...

# %%
#Categorical variables statistics
data.describe(include='object')
# Out:
#        Patient_ID     Sex    Occupation T_Stage N_Stage 6th_Stage  \
# count        4024    4020            43    4024    4024      4024
# unique       4024       2            40       4       3         5
# top         A0012  Female  House Person      T2      N1       IIA
# freq            1    4001             2    1786    2732      1305
#
#                    Differentiated   A_Stage Estrogen_Status  \
# count                        4024      4024            4024
# unique                          4         2               2
# top     Moderately differentiated  Regional        Positive
# freq                         2351      3932            3755
#
#        Progesterone_Status Mortality_Status
# count                 4024             4024
# unique                   2                7
# top               Positive            Alive
# freq                  3326             3399

# %%
#Remove the Occupation column
data=data.drop(columns=['Occupation'])

# %%
#Display first few rows
data.head()
# Out:
#   Patient_ID  Month_of_Birth   Age     Sex T_Stage N_Stage 6th_Stage  \
# 0      A0012              12  68.0  Female      T1      N1       IIA
# 1      A0013              12  50.0  Female      T2      N2      IIIA
# 2      A0014              11  58.0  Female      T3      N3      IIIC
# 3      A0015               3  58.0  Female      T1      N1       IIA
# 4      A0016               1  47.0  Female      T2      N1       IIB
#
#               Differentiated  Grade   A_Stage  Tumor_Size Estrogen_Status  \
# 0      Poorly differentiated      3  Regional         4.0        Positive
# 1  Moderately differentiated      2  Regional        35.0        Positive
# 2  Moderately differentiated      2  Regional        63.0        Positive
# 3      Poorly differentiated      3  Regional        18.0        Positive
# 4      Poorly differentiated      3  Regional        41.0        Positive
#
#   Progesterone_Status  Regional_Node_Examined  Reginol_Node_Positive  \
# ...

# %%
import plotly.express as px

# %%
#Box plot to detect outliers
Age_fig = px.box(data, x='Age')
Age_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Using  IQR statistical method to find outliers
def find_outliers_IQR(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    IQR = q3 - q1
    outliers = data[((data < (q1 - 1.5 * IQR)) | (data > (q3 + 1.5 * IQR)))]
    return outliers

# %%
outliers = find_outliers_IQR(data['Age'])
print("number of outliers: "+ str(len(outliers)))
outliers
# Out:
# number of outliers: 4
# 142    180.0
# 212    -50.0
# 522    502.0
# 842     89.0
# Name: Age, dtype: float64

# %%
data.drop(data.index[[142,212,522,842]],inplace=True)

# %%
#check the unique values in the variable Sex
data['Sex'].unique()
# Out:
# array(['Female', '1', nan], dtype=object)

# %%
#encode the categorical values for the variable Sex
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()

label_encoder=preprocessing.LabelEncoder()
data['Sex']=label_encoder.fit_transform(data['Sex'])

# %%
#Display first few rows
data.head()
# Out:
#   Patient_ID  Month_of_Birth   Age  Sex T_Stage N_Stage 6th_Stage  \
# 0      A0012              12  68.0    1      T1      N1       IIA
# 1      A0013              12  50.0    1      T2      N2      IIIA
# 2      A0014              11  58.0    1      T3      N3      IIIC
# 3      A0015               3  58.0    1      T1      N1       IIA
# 4      A0016               1  47.0    1      T2      N1       IIB
#
#               Differentiated  Grade   A_Stage  Tumor_Size Estrogen_Status  \
# 0      Poorly differentiated      3  Regional         4.0        Positive
# 1  Moderately differentiated      2  Regional        35.0        Positive
# 2  Moderately differentiated      2  Regional        63.0        Positive
# 3      Poorly differentiated      3  Regional        18.0        Positive
# 4      Poorly differentiated      3  Regional        41.0        Positive
#
#   Progesterone_Status  Regional_Node_Examined  Reginol_Node_Positive  \
# ...

# %%
#Calculate the mean and replace missing value with the calculated values
Mean_Age = data['Age'].mean()
Mean_Tumor_Size = data['Tumor_Size'].mean()
Mean_Regional_Node_Examined= data['Regional_Node_Examined'].mean()

data['Age'].fillna(Mean_Age, inplace=True)
data['Tumor_Size'].fillna(Mean_Tumor_Size, inplace=True)
data['Regional_Node_Examined'].fillna(Mean_Regional_Node_Examined, inplace=True)
# Out:
# <ipython-input-23-b2ed8f28d936>:5: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# <ipython-input-23-b2ed8f28d936>:6: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
#Display the percentage of missing values
data.isna().sum()/len(data)*100
# Out:
# Patient_ID                0.0
# Month_of_Birth            0.0
# Age                       0.0
# Sex                       0.0
# T_Stage                   0.0
# N_Stage                   0.0
# 6th_Stage                 0.0
# Differentiated            0.0
# Grade                     0.0
# A_Stage                   0.0
# Tumor_Size                0.0
# Estrogen_Status           0.0
# Progesterone_Status       0.0
# Regional_Node_Examined    0.0
# Reginol_Node_Positive     0.0
# Survival_Months           0.0
# Mortality_Status          0.0
# dtype: float64

# %%
#Convert float columns to Integer
data = data.astype({"Age":"int","Tumor_Size":"int","Regional_Node_Examined":"int" })

# %%
#Keep only relevant columns for classification
classification_data = data[['Age','Sex','Tumor_Size','Grade','Regional_Node_Examined','Reginol_Node_Positive','Mortality_Status']]

# %%
#Save cleaned classification dataset
classification_data.to_csv('classification_data.csv', index=False)

# %%
#Filter dataset for only deceased patients
regression_data=data[data['Mortality_Status']=='Dead']

# %%
#Keep only relevant columns for regression
regression_data = regression_data[['Age','Tumor_Size','Regional_Node_Examined','Reginol_Node_Positive', 'Grade','Survival_Months']]

# %%
#Save cleaned regression dataset
regression_data.to_csv('regression_data.csv', index=False)

# %%
#Save full cleaned dataset
data.to_csv('full_cleaned_data.csv', index=False)
